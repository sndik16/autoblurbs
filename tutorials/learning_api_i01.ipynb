# %% [markdown]
# Keywords:
# software development, api, applications, communication, data,

# %% [markdown]
# I was looking for a quick and simple example on how to use api with python.
# I did not find it, but started studying the info available after a google search, the first few dozen weblinks or so (I skipped the videos and I skipped the AI for now).
#
# I was looking for something where I don't need to install a bunch of stuff, something easy to implement and learn from. I can build on it more if needed later.
#
# I consulted these websites.

# %% [markdown]
# # Blog with Postman
#
# This website had a nice graphic of what API does, a circular one
# https://blog.postman.com/how-to-build-an-api-in-python/
#
# I also liked the simple definition right at the beginning of what api does.
#
# Learning points:
# 1. API = "application programming interface"
# 2. API "facilitates communication between two computer systems", is their definition.
#
# However, I did not like that it needed me to install a bunch of staff that I did not have, so I moved to another source, while keeping it in mind in case nothing else comes up.

# %% [markdown]
# # Article from Geeksforgeeks
# In the following article, it looked like they promised (in the first paragraph) to start from the basics,
# https://www.geeksforgeeks.org/websites-apps/how-to-use-an-api-the-complete-guide/
#
#
# As I already scanned several pages, I was already familiar with the key concepts of endopint, request, and response, but it was nice to see a short description of what each does, and few other ones as well.
#
# At this point, I can imagine giving a link to access, such as a video short youtube link to one of my youtube shorts, but how to populate something into the comments? How will a program know how to find the Comments section and put a comment there? Reading on.
#
# I question myself, am I trying to do something hard? Maybe the easiest way to start using API is not to add a comment, but use api for something else? Such as get some data? Let's read on and see.
#
# I see that 'getting data' is confirmed to be probably the easy way to start using API.
# However, I don't like the rest of the article, as it is not practical, meaning, it does not provide a real example, it's a fake example and is extensive.
#
# I also don't know at this point whether to use cURL or response... Response starts to make sense a little bit, so maybe I start with that.

# %% [markdown]
# Looked like the next few articles used "requests" as the way to go with the python api
# So, I will try to read its documentation directly and see if I can do something myself, or maybe there is a simple example
# Also, instead of pip install, let's see if I can add it in Anaconda environment, the 'requests' package

# %% [markdown]
# # Response documentation

# %% [markdown]
# I tried just importing the requests to see if I already have it, and don't need to install it. Indeed, I had it.

# %%
import requests

# %% [markdown]
# # The docs
#
# I started reading the documentation, https://requests.readthedocs.io/en/latest/api/
#
#
# So, it is an object, and I am new to those. I scanned to see that you input something into it and it outputs something. When you input something, it is called 'request' or 'requests.request', where you also specify the URL of where to go. And the output is called 'response'. It's still a littly gray how to exactly do something, but keywords are understandable to an English speaker as indicating a meaning behind them, such as GET to get something, and similarly POST, PUT, and more. How they work exactly is still a mystery, but I noticed in my peripheral that there is a "Quickstart" link, I go there next after scrolling to the end of the page just to make sure there is no simple example lurking there somewhere - there was not, but was a bunch more details, maybe which will be consulted by me further on, once I figure out what exactly I will be doing.

# %% [markdown]
# # Quickstart
# https://requests.readthedocs.io/en/latest/user/quickstart/
#
# Yay, I see an example that appears to be relatively easy, but I hold my breath. Let's try it.
# Yeah, after reading it through, it is not simple, as it claims to be. I have no idea what they mean in terms of the data parameters.... what's happening here????

# %% [markdown]
# what does it mean, to 'get' a webpage??

# %%
#Let's try on my own website
my_request = requests.get(astronomygo.com)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Let's try on my own website
# ----> 2 my_request = requests.get(astronomygo.com)
#
# NameError: name 'astronomygo' is not defined

# %%
# I need to put quote marks around the URL!
my_request = requests.get('https://www.astronomygo.com/')

# %%
my_request
# Out:
# <Response [200]>

# %% [markdown]
# What is this response 200????

# %% [markdown]
# Obviously, the documentation is for someone with more experience :(
# I have 10+ years of python experience, but never tried to link to another website, starting now, why should this be so hard????

# %% [markdown]
# I check the documentation with W3schools, https://www.w3schools.com/python/ref_requests_response.asp
#
# More questions come up, what is the HTTP request?
#
# Looks like I can learn more from this resource.
#
# Learning points.
# 1. The requests.Response() object has bunch of information and capabilities inside / or associated with it, such as the ability to give you the url link, such as ability to give you indication of the status.
# 2. Status codes are numerical, such as 200 is OK (that answers the earlier question!)

# %% [markdown]
# #Okay, so now I can do something with what I 'got' from my own website

# %% [markdown]
# # I can check the status of my website

# %%
print (my_request.url)
# Out:
# https://www.astronomygo.com/

# %%
#Ha-ha that's my website, okay, so this little 'my_request' thingy is 'talking' to my website.

# %%
#Let's finally get the status

# %%
my_request.url
# Out:
# 'https://www.astronomygo.com/'

# %%
my_request.status_code
# Out:
# 200

# %%
print (my_request.status_code)
# Out:
# 200

# %% [markdown]
# Let's remember from the earlier that this code means that my website works and is OK. That's always good.

# %% [markdown]
# # Moving on

# %% [markdown]
# I keep seeing this word 'header', I wonder what it means in this context.

# %% [markdown]
# More questions come up, where is the get and post and put and other staff???
#
# Okay, I know how to learn something about the status of my webpage, but how to grab data for example???

# %% [markdown]
# # Let's try the headers

# %%
my_request.headers
# Out:
# {'Date': 'Tue, 22 Jul 2025 09:42:40 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Powered-By': 'PHP/7.4.33', 'Link': '<https://www.astronomygo.com/wp-json/>; rel="https://api.w.org/", <https://www.astronomygo.com/wp-json/wp/v2/pages/4>; rel="alternate"; title="JSON"; type="application/json", <https://www.astronomygo.com/>; rel=shortlink', 'Report-To': '{"group":"cf-nel","max_age":604800,"endpoints":[{"url":"https://a.nel.cloudflare.com/report/v4?s=OBgSfnOoRSHXHerknXPgxkB04T7aqKNd9N0Cyk7wbEfEFCJhHIPJO8m%2BZHGtF3Kudo3Oc%2FnckDebWJrSv%2BZRno%2B0bJ%2F9WZlrv2vgYhli6GxPa0M%3D"}]}', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'Alt-Svc': 'h3=":443"; ma=86400', 'Cf-Cache-Status': 'DYNAMIC', 'Nel': '{"report_to":"cf-nel","success_fraction":0.0,"max_age":604800}', 'Content-Encoding': 'br', 'Server': 'cloudflare', 'CF-RAY': '9631fd3f9f7c3a56-ARN'}

# %%
# I have no idea what it means...

# %%
#let's try another headers related thing
print(my_request.links)
# Out:
# {'https://api.w.org/': {'url': 'https://www.astronomygo.com/wp-json/', 'rel': 'https://api.w.org/'}, 'alternate': {'url': 'https://www.astronomygo.com/wp-json/wp/v2/pages/4', 'rel': 'alternate', 'title': 'JSON', 'type': 'application/json'}, 'shortlink': {'url': 'https://www.astronomygo.com/', 'rel': 'shortlink'}}

# %% [markdown]
# # I notice the link to the Requests in W3schools, let's see if they have something more digestable for me at this point,
# https://www.w3schools.com/python/module_requests.asp

# %% [markdown]
# Let's investigate the GET
# https://www.w3schools.com/python/ref_requests_get.asp

# %% [markdown]
# Okay, it looks like besides the link there is some parameters that need to go into it, but I still don't see how to get some data

# %% [markdown]
# I look at a few website, this one seems to be understandable at this point,
# https://www.dataquest.io/blog/api-in-python/
#
#
# Looks like I need json

# %% [markdown]
# # What is json?

# %% [markdown]
# There is a python package, let's see if I can import it already.

# %%
import json
#Yes, I can!

# %%
print(my_request.json())  
#According to W3schools, this 'returs' the JSON object of the result, what????
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/opt/anaconda3/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# File ~/opt/anaconda3/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/opt/anaconda3/lib/python3.8/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(my_request.json())
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# An error, maybe it is not written in json format? Let's try another website

# %%
example_url = 'https://api.github.com/events' #remember the quote marks around the url!
# after tryig github and w3schools links, I finally found one that has json decoding from documentation

example_request = requests.get(example_url)

# https://requests.readthedocs.io/en/latest/user/quickstart/#json-response-content

# %%
print(example_request.json())
# Out:
# [{'id': '52384363132', 'type': 'PushEvent', 'actor': {'id': 57111813, 'login': 'jasonberlin', 'display_login': 'jasonberlin', 'gravatar_id': '', 'url': 'https://api.github.com/users/jasonberlin', 'avatar_url': 'https://avatars.githubusercontent.com/u/57111813?'}, 'repo': {'id': 1023187754, 'name': 'jasonberlin/drive-scout', 'url': 'https://api.github.com/repos/jasonberlin/drive-scout'}, 'payload': {'repository_id': 1023187754, 'push_id': 25646823624, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '8558efeb13711715b1fd8142e80c7550ff208c94', 'before': '2a910f1dd1b8cc50e5d8de25e1b08b9eca5bc579', 'commits': [{'sha': '8558efeb13711715b1fd8142e80c7550ff208c94', 'author': {'email': '57111813+jasonberlin@users.noreply.github.com', 'name': 'jasonberlin'}, 'message': 'Update index.html', 'distinct': True, 'url': 'https://api.github.com/repos/jasonberlin/drive-scout/commits/8558efeb13711715b1fd8142e80c7550ff208c94'}]}, 'public': True, 'created_at': '2025-07-22T09:59:01Z'}, {'id': '52384363110', 'type': 'PushEvent', 'actor': {'id': 154874841, 'login': 'narendra143t', 'display_login': 'narendra143t', 'gravatar_id': '', 'url': 'https://api.github.com/users/narendra143t', 'avatar_url': 'https://avatars.githubusercontent.com/u/154874841?'}, 'repo': {'id': 1024048604, 'name': 'narendra143t/landing-page', 'url': 'https://api.github.com/repos/narendra143t/landing-page'}, 'payload': {'repository_id': 1024048604, 'push_id': 25646823639, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'da0f4f5aca8c072b19e8c0a976e2c8d13356dc7a', 'before': '1e0195af9ed1fb59a63cfd977ad66141d2b11d91', 'commits': [{'sha': 'da0f4f5aca8c072b19e8c0a976e2c8d13356dc7a', 'author': {'email': 'Narendrakumar93660@gmail.com', 'name': 'Narendra'}, 'message': 'payment', 'distinct': True, 'url': 'https://api.github.com/repos/narendra143t/landing-page/commits/da0f4f5aca8c072b19e8c0a976e2c8d13356dc7a'}]}, 'public': True, 'created_at': '2025-07-22T09:59:01Z'}, {'id': '52384363135', 'type': 'PushEvent', 'actor': {'id': 208483709, 'login': 'shaehabultra', 'display_login': 'shaehabultra', 'gravatar_id': '', 'url': 'https://api.github.com/users/shaehabultra', 'avatar_url': 'https://avatars.githubusercontent.com/u/208483709?'}, 'repo': {'id': 970201570, 'name': 'shaehabultra/test', 'url': 'https://api.github.com/repos/shaehabultra/test'}, 'payload': {'repository_id': 970201570, 'push_id': 25646823644, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'fdb32b5454da1281fd311e264bde2c07ae42bc80', 'before': 'ff8674e33eab887f01b7f1f93190895448874620', 'commits': [{'sha': 'fdb32b5454da1281fd311e264bde2c07ae42bc80', 'author': {'email': 'friedcamel2003@gmail.com', 'name': 'shaehabultra'}, 'message': 'Update users data by 「^3Evils RP ✦^0」 ^0- 「 سيرفر عرب ايفلز للحياة الواقعية」 - 「^3discord.gg/ae3^0」', 'distinct': True, 'url': 'https://api.github.com/repos/shaehabultra/test/commits/fdb32b5454da1281fd311e264bde2c07ae42bc80'}]}, 'public': True, 'created_at': '2025-07-22T09:59:01Z'}, {'id': '52384363105', 'type': 'IssueCommentEvent', 'actor': {'id': 135371107, 'login': 'michaelortnerit', 'display_login': 'michaelortnerit', 'gravatar_id': '', 'url': 'https://api.github.com/users/michaelortnerit', 'avatar_url': 'https://avatars.githubusercontent.com/u/135371107?'}, 'repo': {'id': 980675910, 'name': 'operacle/checkcle', 'url': 'https://api.github.com/repos/operacle/checkcle'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/operacle/checkcle/issues/72', 'repository_url': 'https://api.github.com/repos/operacle/checkcle', 'labels_url': 'https://api.github.com/repos/operacle/checkcle/issues/72/labels{/name}', 'comments_url': 'https://api.github.com/repos/operacle/checkcle/issues/72/comments', 'events_url': 'https://api.github.com/repos/operacle/checkcle/issues/72/events', 'html_url': 'https://github.com/operacle/checkcle/issues/72', 'id': 3236281106, 'node_id': 'I_kwDOOnPtRs7A5bsS', 'number': 72, 'title': 'How to add Instance Mo ...

# %% [markdown]
# Okay, so it is some sort of output in curly brakets with several pieces of info in it

# %% [markdown]
# # I read up on DataQuest what in the world is JSON????
# (I like that they have some explanation there, hopefully it's enough for me to get started).
#
# Learning points:
# 1. JSON = javascript object notation (wow, it's used in #AI!)
# 2. JSON output seems to be like a python dictionary in structure
# 3. As we saw, there is already json package in python ;D
#
# It seemed to me that this article was diving too deep into the json, instead of json application with response, so I saved it for a moment and left it to see the other blog articles, maybe they had something more direct that I Could understand without extra bla-bla, which I could consult later after building one basic example first.

# %% [markdown]
# # Some digging with no avail
#
# I scan an example on Airbyte, but it does not break down the process with json
# https://airbyte.com/data-engineering-resources/how-to-use-api-in-python
#
#
# I scan Datacamp article, also no practical end-to-end example and requires to install more things
# https://www.datacamp.com/tutorial/python-api
#
#
# Back to Geeksforgeeks, for another API-related article,
# https://www.geeksforgeeks.org/python/python-api-tutorial-getting-started-with-apis/

# %% [markdown]
# # Data and json, based on Geeksforgeeks

# %%
data = example_request.json() # Okay, the json thingy contains the data!!! We are getting closer

# %%
data
# Out:
# [{'id': '52383567006',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 1599151,
#    'name': 'alphagov/static',
#    'url': 'https://api.github.com/repos/alphagov/static'},
#   'payload': {'ref': 'dependabot/bundler/rubocop-govuk-5.1.18',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'GOV.UK static files and resources',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 596977,
#    'login': 'alphagov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alphagov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/596977?'}},
#  {'id': '52383566977',
#   'type': 'PushEvent',
#   'actor': {'id': 217809078,
#    'login': 'IntisarMustafa',
#    'display_login': 'IntisarMustafa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IntisarMustafa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/217809078?'},
#   'repo': {'id': 1007950965,
#    'name': 'IntisarMustafa/7',
#    'url': 'https://api.github.com/repos/IntisarMustafa/7'},
#   'payload': {'repository_id': 1007950965,
#    'push_id': 25646457200,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1d0317b70801c95b8283cc6925dc579fd2400305',
#    'before': '14f5c3056df8ed4225013887c5beb5e00baed45e',
#    'commits': [{'sha': '1d0317b70801c95b8283cc6925dc579fd2400305',
#      'author': {'email': 'int.mustafa@unrwa.org', 'name': 'IntisarMustafa'},
#      'message': 'Update u2l2p5.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IntisarMustafa/7/commits/1d0317b70801c95b8283cc6925dc579fd2400305'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566988',
#   'type': 'CreateEvent',
#   'actor': {'id': 204291824,
#    'login': 'frostyxsec',
#    'display_login': 'frostyxsec',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/frostyxsec',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/204291824?'},
#   'repo': {'id': 1024167614,
#    'name': 'frostyxsec/RyuuGuard',
#    'url': 'https://api.github.com/repos/frostyxsec/RyuuGuard'},
#   'payload': {'ref': 'release',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': 'Simple OpenSource IDSA in server engine with live notification',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566914',
#   'type': 'PushEvent',
#   'actor': {'id': 51156018,
#    'login': 'ianjon3s',
#    'display_login': 'ianjon3s',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ianjon3s',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51156018?'},
#   'repo': {'id': 282647716,
#    'name': 'theopensystemslab/planx-new',
#    'url': 'https://api.github.com/repos/theopensystemslab/planx-new'},
#   'payload': {'repository_id': 282647716,
#    'push_id': 25646457143,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ian/lps-empty-applications-page',
#    'head': '836364e30bed7eb930ea41e3f302e285979ad2df',
#    'before': '3e99f6e7ddb59fb637e32740e7d54513b14dd2ca',
#    'commits': [{'sha': '836364e30bed7eb930ea41e3f302e285979ad2df',
#      'author': {'email': 'hello@ianjo.uk', 'name': 'Ian Jones'},
#      'message': 'use styled-content',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/theopensystemslab/planx-new/commits/836364e30bed7eb930ea41e3f302e285979ad2df'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 38584178,
#    'login': 'theopensystemslab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/theopensystemslab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38584178?'}},
#  {'id': '52383566957',
#   'type': 'PushEvent',
#   'actor': {'id': 191581607,
#    'login': 'DrXSolutions6',
#    'display_login': 'DrXSolutions6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DrXSolutions6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/191581607?'},
#   'repo': {'id': 902811413,
#    'name': 'DrXSolutions6/Image-Dr.X-Solution-6',
#    'url': 'https://api.github.com/repos/DrXSolutions6/Image-Dr.X-Solution-6'},
#   'payload': {'repository_id': 902811413,
#    'push_id': 25646457084,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '272d9c7aab5c34727f3052882e515fcc56124b3c',
#    'before': 'c7f81705c253bb285ac82c3bf656e2fd2d46784d',
#    'commits': [{'sha': '272d9c7aab5c34727f3052882e515fcc56124b3c',
#      'author': {'email': 'drx.aesthetic@gmail.com', 'name': 'Dr.x Solution'},
#      'message': 'upload 01983183-986d-7985-9a4f-3a15a8318665',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DrXSolutions6/Image-Dr.X-Solution-6/commits/272d9c7aab5c34727f3052882e515fcc56124b3c'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566884',
#   'type': 'PushEvent',
#   'actor': {'id': 106555838,
#    'login': 'AbdulTheActivePiecer',
#    'display_login': 'AbdulTheActivePiecer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AbdulTheActivePiecer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106555838?'},
#   'repo': {'id': 573661753,
#    'name': 'activepieces/activepieces',
#    'url': 'https://api.github.com/repos/activepieces/activepieces'},
#   'payload': {'repository_id': 573661753,
#    'push_id': 25646457076,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n_main',
#    'head': '33a04d6a4b116c93854cd62a93cf5fbe1d6fd94f',
#    'before': 'c06995ddb99bfb9313ade3ea51a569030751cf9a',
#    'commits': [{'sha': '33a04d6a4b116c93854cd62a93cf5fbe1d6fd94f',
#      'author': {'email': '106555838+AbdulTheActivePiecer@users.noreply.github.com',
#       'name': 'Abdul'},
#      'message': 'New translations translation.json (Chinese Simplified)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/activepieces/activepieces/commits/33a04d6a4b116c93854cd62a93cf5fbe1d6fd94f'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 99494700,
#    'login': 'activepieces',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/activepieces',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99494700?'}},
#  {'id': '52383566938',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 944642230,
#    'name': 'dperkosan/gateway',
#    'url': 'https://api.github.com/repos/dperkosan/gateway'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/dperkosan/gateway/pulls/3',
#     'id': 2684887974,
#     'node_id': 'PR_kwDOOE4Yts6gCCOm',
#     'html_url': 'https://github.com/dperkosan/gateway/pull/3',
#     'diff_url': 'https://github.com/dperkosan/gateway/pull/3.diff',
#     'patch_url': 'https://github.com/dperkosan/gateway/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/dperkosan/gateway/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump form-data from 4.0.1 to 4.0.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Bumps [form-data](https://github.com/form-data/form-data) from 4.0.1 to 4.0.4.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/form-data/form-data/blob/master/CHANGELOG.md">form-data\'s changelog</a>.</em></p>\n<blockquote>\n<h2><a href="https://github.com/form-data/form-data/compare/v4.0.3...v4.0.4">v4.0.4</a> - 2025-07-16</h2>\n<h3>Commits</h3>\n<ul>\n<li>[meta] add <code>auto-changelog</code> <a href="https://github.com/form-data/form-data/commit/811f68282fab0315209d0e2d1c44b6c32ea0d479"><code>811f682</code></a></li>\n<li>[Tests] handle predict-v8-randomness failures in node &lt; 17 and node &gt; 23 <a href="https://github.com/form-data/form-data/commit/1d11a76434d101f22fdb26b8aef8615f28b98402"><code>1d11a76</code></a></li>\n<li>[Fix] Switch to using <code>crypto</code> random for boundary values <a href="https://github.com/form-data/form-data/commit/3d1723080e6577a66f17f163ecd345a21d8d0fd0"><code>3d17230</code></a></li>\n<li>[Tests] fix linting errors <a href="https://github.com/form-data/form-data/commit/5e340800b5f8914213e4e0378c084aae71cfd73a"><code>5e34080</code></a></li>\n<li>[meta] actually ensure the readme backup isn’t published <a href="https://github.com/form-data/form-data/commit/316c82ba93fd4985af757b771b9a1f26d3b709ef"><code>316c82b</code></a></li>\n<li>[Dev Deps] update <code>@ljharb/eslint-config</code> <a href="https://github.com/form-data/form-data/commit/58c25d76406a5b0dfdf54045cf252563f2bbda8d"><code>58c25d7</code></a></li>\n<li>[meta] fix readme capitalization <a href="https://github.com/form-data/form-data/commit/2300ca19595b0ee96431e868fe2a40db79e41c61"><code>2300ca1</code></a></li>\n</ul>\n<h2><a href="https://github.com/form-data/form-data/compare/v4.0.2...v4.0.3">v4.0.3</a> - 2025-06-05</h2>\n<h3>Fixed</h3>\n<ul>\n<li>[Fix] <code>append</code>: avoid a crash on nullish values <a href="https://redirect.github.com/form-data/form-data/issues/577"><code>[#577](https://github.com/form-data/form-data/issues/577)</code></a></li>\n</ul>\n<h3>Commits</h3>\n<ul>\n<li>[eslint] use a shared config <a href="https://github.com/form-data/form-data/commit/426ba9ac440f95d1998dac9a5cd8d738043b048f"><code>426ba9a</code></a></li>\n<li>[eslint] fix some spacing issues <a href="https://github.com/form-data/form-data/commit/20941917f0e9487e68c564ebc3157e23609e2939"><code>2094191</code></a></li>\n<li>[Refactor] use <code>hasown</code> <a href="https://github.com/form-data/form-data/commit/81ab41b46fdf34f5d89d7ff30b513b0925febfaa"><code>81ab41b</code></a></li>\n<li>[Fix] validate boundary type in <code>setBoundary()</code> method <a href="https://github.com/form-data/form-data/commit/8d8e4693093519f7f18e3c597d1e8df8c493de9e"><code>8d8e469</code></a></li>\n<li>[Tests] add tests to check the behavior of <code>getBoundary</code> with non-strings <a href="https://github.com/form-data/form-data/commit/837b8a1f7562bfb8bda74f3fc538adb7a5858995"><code>837b8a1</code></a></li>\n<li>[Dev Deps] remove unused deps <a href="https://github.com/form-data/form-data/commit/870e4e665935e701bf983a051244ab928e62d58e"><code>870e4e6</code></a></li>\n<li>[meta] remove local commit hooks <a href="https://github.com/form-data/form-data/commit/e6e83ccb545a5619ed6cd04f31d5c2f655eb633e"><code>e6e83cc</code></a></li>\n<li>[Dev Deps] update <code>eslint</code> <a href="https://github.com/form-data/form-data/commit/4066fd6f65992b62fa324a6474a9292a4f88c916"><code>4066fd6</code></a></li>\n<li>[meta] fix scripts to use prepublishOnly <a href="https://github.com/form-data/form-data/commit/c4bbb13c0ef669916657bc129341301b1d331d75"><code>c4bbb13</code></a></li>\n</ul>\n<h2><a href="https://github.com/form-data/form-data/compare/v4.0.1...v4.0.2">v4.0.2</a> - 2025-02-14</h2>\n<h3>Merged</h3>\n<ul>\n<li>[Fix] set\xa0<code>Symbol.toStringTag</code> when\xa0available <a href="https://redirect.github.com/form-data/form-data/pull/573"><code>[#573](https://github.com/form-data/form-data/issues/573)</code></a></li> ...
#     'created_at': '2025-07-22T09:42:47Z',
#     'updated_at': '2025-07-22T09:42:47Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 8258308179,
#       'node_id': 'LA_kwDOOE4Yts8AAAAB7DvIUw',
#       'url': 'https://api.github.com/repos/dperkosan/gateway/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 8535289242,
#       'node_id': 'LA_kwDOOE4Yts8AAAAB_L4tmg',
#       'url': 'https://api.github.com/repos/dperkosan/gateway/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update javascript code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/dperkosan/gateway/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/dperkosan/gateway/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/dperkosan/gateway/statuses/e880b901cb286fcdc2b0c6cb9715a7654a345505',
#     'head': {'label': 'dperkosan:dependabot/npm_and_yarn/form-data-4.0.4',
#      'ref': 'dependabot/npm_and_yarn/form-data-4.0.4',
#      'sha': 'e880b901cb286fcdc2b0c6cb9715a7654a345505',
#      'user': {'login': 'dperkosan',
#       'id': 12428970,
#       'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dperkosan',
#       'html_url': 'https://github.com/dperkosan',
#       'followers_url': 'https://api.github.com/users/dperkosan/followers',
#       'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#       'repos_url': 'https://api.github.com/users/dperkosan/repos',
#       'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 944642230,
#       'node_id': 'R_kgDOOE4Ytg',
#       'name': 'gateway',
#       'full_name': 'dperkosan/gateway',
#       'private': False,
#       'owner': {'login': 'dperkosan',
#        'id': 12428970,
#        'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dperkosan',
#        'html_url': 'https://github.com/dperkosan',
#        'followers_url': 'https://api.github.com/users/dperkosan/followers',
#        'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#        'repos_url': 'https://api.github.com/users/dperkosan/repos',
#        'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/dperkosan/gateway',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/dperkosan/gateway',
#       'forks_url': 'https://api.github.com/repos/dperkosan/gateway/forks',
#       'keys_url': 'https://api.github.com/repos/dperkosan/gateway/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dperkosan/gateway/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dperkosan/gateway/teams',
#       'hooks_url': 'https://api.github.com/repos/dperkosan/gateway/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dperkosan/gateway/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dperkosan/gateway/events',
#       'assignees_url': 'https://api.github.com/repos/dperkosan/gateway/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dperkosan/gateway/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dperkosan/gateway/tags',
#       'blobs_url': 'https://api.github.com/repos/dperkosan/gateway/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dperkosan/gateway/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dperkosan/gateway/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dperkosan/gateway/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dperkosan/gateway/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dperkosan/gateway/languages',
#       'stargazers_url': 'https://api.github.com/repos/dperkosan/gateway/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dperkosan/gateway/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dperkosan/gateway/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dperkosan/gateway/subscription',
#       'commits_url': 'https://api.github.com/repos/dperkosan/gateway/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dperkosan/gateway/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dperkosan/gateway/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dperkosan/gateway/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dperkosan/gateway/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dperkosan/gateway/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dperkosan/gateway/merges',
#       'archive_url': 'https://api.github.com/repos/dperkosan/gateway/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dperkosan/gateway/downloads',
#       'issues_url': 'https://api.github.com/repos/dperkosan/gateway/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dperkosan/gateway/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dperkosan/gateway/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dperkosan/gateway/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dperkosan/gateway/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dperkosan/gateway/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dperkosan/gateway/deployments',
#       'created_at': '2025-03-07T17:54:16Z',
#       'updated_at': '2025-03-09T13:32:21Z',
#       'pushed_at': '2025-07-22T09:42:47Z',
#       'git_url': 'git://github.com/dperkosan/gateway.git',
#       'ssh_url': 'git@github.com:dperkosan/gateway.git',
#       'clone_url': 'https://github.com/dperkosan/gateway.git',
#       'svn_url': 'https://github.com/dperkosan/gateway',
#       'homepage': None,
#       'size': 242,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'dperkosan:main',
#      'ref': 'main',
#      'sha': '2dfa6433b12e7105b9c34af6eb7ff5beeda81e6f',
#      'user': {'login': 'dperkosan',
#       'id': 12428970,
#       'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dperkosan',
#       'html_url': 'https://github.com/dperkosan',
#       'followers_url': 'https://api.github.com/users/dperkosan/followers',
#       'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#       'repos_url': 'https://api.github.com/users/dperkosan/repos',
#       'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 944642230,
#       'node_id': 'R_kgDOOE4Ytg',
#       'name': 'gateway',
#       'full_name': 'dperkosan/gateway',
#       'private': False,
#       'owner': {'login': 'dperkosan',
#        'id': 12428970,
#        'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dperkosan',
#        'html_url': 'https://github.com/dperkosan',
#        'followers_url': 'https://api.github.com/users/dperkosan/followers',
#        'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#        'repos_url': 'https://api.github.com/users/dperkosan/repos',
#        'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/dperkosan/gateway',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/dperkosan/gateway',
#       'forks_url': 'https://api.github.com/repos/dperkosan/gateway/forks',
#       'keys_url': 'https://api.github.com/repos/dperkosan/gateway/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dperkosan/gateway/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dperkosan/gateway/teams',
#       'hooks_url': 'https://api.github.com/repos/dperkosan/gateway/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dperkosan/gateway/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dperkosan/gateway/events',
#       'assignees_url': 'https://api.github.com/repos/dperkosan/gateway/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dperkosan/gateway/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dperkosan/gateway/tags',
#       'blobs_url': 'https://api.github.com/repos/dperkosan/gateway/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dperkosan/gateway/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dperkosan/gateway/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dperkosan/gateway/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dperkosan/gateway/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dperkosan/gateway/languages',
#       'stargazers_url': 'https://api.github.com/repos/dperkosan/gateway/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dperkosan/gateway/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dperkosan/gateway/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dperkosan/gateway/subscription',
#       'commits_url': 'https://api.github.com/repos/dperkosan/gateway/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dperkosan/gateway/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dperkosan/gateway/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dperkosan/gateway/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dperkosan/gateway/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dperkosan/gateway/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dperkosan/gateway/merges',
#       'archive_url': 'https://api.github.com/repos/dperkosan/gateway/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dperkosan/gateway/downloads',
#       'issues_url': 'https://api.github.com/repos/dperkosan/gateway/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dperkosan/gateway/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dperkosan/gateway/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dperkosan/gateway/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dperkosan/gateway/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dperkosan/gateway/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dperkosan/gateway/deployments',
#       'created_at': '2025-03-07T17:54:16Z',
#       'updated_at': '2025-03-09T13:32:21Z',
#       'pushed_at': '2025-07-22T09:42:47Z',
#       'git_url': 'git://github.com/dperkosan/gateway.git',
#       'ssh_url': 'git@github.com:dperkosan/gateway.git',
#       'clone_url': 'https://github.com/dperkosan/gateway.git',
#       'svn_url': 'https://github.com/dperkosan/gateway',
#       'homepage': None,
#       'size': 242,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/3'},
#      'html': {'href': 'https://github.com/dperkosan/gateway/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/dperkosan/gateway/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/dperkosan/gateway/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/dperkosan/gateway/statuses/e880b901cb286fcdc2b0c6cb9715a7654a345505'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 35,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566861',
#   'type': 'PushEvent',
#   'actor': {'id': 125531081,
#    'login': 'quyk67uet',
#    'display_login': 'quyk67uet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/quyk67uet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125531081?'},
#   'repo': {'id': 1021545392,
#    'name': 'quyk67uet/mmqa_chatbot',
#    'url': 'https://api.github.com/repos/quyk67uet/mmqa_chatbot'},
#   'payload': {'repository_id': 1021545392,
#    'push_id': 25646457174,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ab0cfbcdad55aba532290f4783dd215d2be3084a',
#    'before': 'dd664ce82b3049ed243a6b5262b7e338774fb6f5',
#    'commits': [{'sha': 'ab0cfbcdad55aba532290f4783dd215d2be3084a',
#      'author': {'email': '22028190@vnu.edu.vn', 'name': 'quyk67uet'},
#      'message': 'Update 80',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quyk67uet/mmqa_chatbot/commits/ab0cfbcdad55aba532290f4783dd215d2be3084a'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566901',
#   'type': 'PushEvent',
#   'actor': {'id': 117032989,
#    'login': 'ky1nonly',
#    'display_login': 'ky1nonly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ky1nonly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117032989?'},
#   'repo': {'id': 1015288837,
#    'name': 'prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE',
#    'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE'},
#   'payload': {'repository_id': 1015288837,
#    'push_id': 25646457190,
#    'size': 55,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Feat/75-delete-branch',
#    'head': 'd8aed8b6368d8803ee74eeaa448c918ff0a0472f',
#    'before': 'e06b68b6b7b72886b1e5e54cf1d5e0651409525c',
#    'commits': [{'sha': 'a39e84416aff6f1024de417edc33ce8784575c52',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Feat: 기록 병합하기 API 구현',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/a39e84416aff6f1024de417edc33ce8784575c52'},
#     {'sha': '942140d782f1d089b5b74f2b700c18611146e429',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Fix: TransactionManager 적용 전 상태이므로 해당 코드 주석처리 & ToDo 작성',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/942140d782f1d089b5b74f2b700c18611146e429'},
#     {'sha': 'a27c9469722d4f4af0c11a9d3bac0aee2ec5f251',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Refactor: 트랜잭션 처리 방식 변경',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/a27c9469722d4f4af0c11a9d3bac0aee2ec5f251'},
#     {'sha': '61a88579482ce76e27fe38a630d6108b73f8d1c1',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Chore: Swagger 의존성 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/61a88579482ce76e27fe38a630d6108b73f8d1c1'},
#     {'sha': 'c4485e0fe1dbf09429a7aaf32c3ae3275ccea42f',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Chore: Swagger 관련 경로 인증 없이 접근 가능하도록 설정',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/c4485e0fe1dbf09429a7aaf32c3ae3275ccea42f'},
#     {'sha': '1ec30c932dc881c123af00d1beec97b0ba6f8a95',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: DocsaApplication에 Swagger OpenAPI 메타 정보 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/1ec30c932dc881c123af00d1beec97b0ba6f8a95'},
#     {'sha': 'e9b8ca226f6018719765be5ae807b135d410f7c8',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: AuthController Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/e9b8ca226f6018719765be5ae807b135d410f7c8'},
#     {'sha': 'dfddd13722d9c9554ac4d2626e5c3921bd36f483',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: Auth DTO Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/dfddd13722d9c9554ac4d2626e5c3921bd36f483'},
#     {'sha': '67887b1006ca49359947cbd7e7496eb1721b7c8d',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: UserController Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/67887b1006ca49359947cbd7e7496eb1721b7c8d'},
#     {'sha': 'f33c5b5e430f487637adcc9d0d6d84f1bec1fcf0',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: User DTO Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/f33c5b5e430f487637adcc9d0d6d84f1bec1fcf0'},
#     {'sha': '2c9d0227ee97da3effc19f737d58f49877eb0ff6',
#      'author': {'email': '80705450+Jeongmin39@users.noreply.github.com',
#       'name': '한정민'},
#      'message': "Merge branch 'dev' into Docs/80-swagger-auth-user",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/2c9d0227ee97da3effc19f737d58f49877eb0ff6'},
#     {'sha': 'a0acf16ad55879bb6cb3fd2fac4f10be5f168ac6',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : swagger 도입중',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/a0acf16ad55879bb6cb3fd2fac4f10be5f168ac6'},
#     {'sha': '1b0da6f889643f9bd2006ee1fd41d3456b2da5cf',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : swagger url 권한 허용',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/1b0da6f889643f9bd2006ee1fd41d3456b2da5cf'},
#     {'sha': '363e0441cf445bcec9e61f550983dcbc5ae7d028',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Fix: Edge 엔티티의 연관관계 수정',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/363e0441cf445bcec9e61f550983dcbc5ae7d028'},
#     {'sha': '694ff3b733bfe9e7c4ed22af4e74e5050001ff31',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : Save 도메인 1차 스웨거 (구체적인 응답 없음)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/694ff3b733bfe9e7c4ed22af4e74e5050001ff31'},
#     {'sha': '8921625da79d73d147c84a16079efef14481d23d',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Fix: Branch 엔티티의 연관관계 속성 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/8921625da79d73d147c84a16079efef14481d23d'},
#     {'sha': '59969a22dd2f781406355fb285af00b05f2db80c',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': "Merge branch 'dev' into Docs/83-save-swagger",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/59969a22dd2f781406355fb285af00b05f2db80c'},
#     {'sha': 'bdd063a78088052086a4485a5181d68d408ef57c',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Feat: BaseBranch와 TargetBranch가 일치하는지 검사하는 로직 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/bdd063a78088052086a4485a5181d68d408ef57c'},
#     {'sha': '787c2306fc48a757b3a25d297bf43741a99cf9e5',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Test: Merge Commit에 대한 통합테스트',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/787c2306fc48a757b3a25d297bf43741a99cf9e5'},
#     {'sha': '96638c5f308e29e6d2a992809c2598b2b15d4194',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : Save 도메인 디테일 응답 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/96638c5f308e29e6d2a992809c2598b2b15d4194'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 187719732,
#    'login': 'prgrms-web-devcourse-final-project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/prgrms-web-devcourse-final-project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/187719732?'}},
#  {'id': '52383566826',
#   'type': 'PushEvent',
#   'actor': {'id': 173871145,
#    'login': 'rajarshi1912',
#    'display_login': 'rajarshi1912',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rajarshi1912',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/173871145?'},
#   'repo': {'id': 1006877878,
#    'name': 'rajarshi1912/agrowin_module',
#    'url': 'https://api.github.com/repos/rajarshi1912/agrowin_module'},
#   'payload': {'repository_id': 1006877878,
#    'push_id': 25646457157,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/NP',
#    'head': '14ecdbc0de0e31557d0465e9cc84f8ea5acdefb9',
#    'before': 'df91685cdc8f44bf212a3f49d5bb47cb318ca999',
#    'commits': [{'sha': '14ecdbc0de0e31557d0465e9cc84f8ea5acdefb9',
#      'author': {'email': 'rajarshi.chakraborty.ext@bayer.com',
#       'name': 'rajarshi1912'},
#      'message': 'Update fungi_mapping.sql',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rajarshi1912/agrowin_module/commits/14ecdbc0de0e31557d0465e9cc84f8ea5acdefb9'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566847',
#   'type': 'PushEvent',
#   'actor': {'id': 208483709,
#    'login': 'shaehabultra',
#    'display_login': 'shaehabultra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaehabultra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/208483709?'},
#   'repo': {'id': 970201570,
#    'name': 'shaehabultra/test',
#    'url': 'https://api.github.com/repos/shaehabultra/test'},
#   'payload': {'repository_id': 970201570,
#    'push_id': 25646457103,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8b251bcce81569bdd76b13600f9735c5577814a0',
#    'before': 'e3ea34caa7a559ee2bdb30bf0f918af78a688ba6',
#    'commits': [{'sha': '8b251bcce81569bdd76b13600f9735c5577814a0',
#      'author': {'email': 'friedcamel2003@gmail.com', 'name': 'shaehabultra'},
#      'message': 'Update users data by 「^3Evils RP ✦^0」 ^0- 「 سيرفر عرب ايفلز للحياة الواقعية」 - 「^3discord.gg/ae3^0」',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shaehabultra/test/commits/8b251bcce81569bdd76b13600f9735c5577814a0'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566874',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 922448076,
#    'name': 'SakshiPharande/PawsAndAdopt',
#    'url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt'},
#   'payload': {'action': 'opened',
#    'number': 23,
#    'pull_request': {'url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/pulls/23',
#     'id': 2684887988,
#     'node_id': 'PR_kwDONvtwzM6gCCO0',
#     'html_url': 'https://github.com/SakshiPharande/PawsAndAdopt/pull/23',
#     'diff_url': 'https://github.com/SakshiPharande/PawsAndAdopt/pull/23.diff',
#     'patch_url': 'https://github.com/SakshiPharande/PawsAndAdopt/pull/23.patch',
#     'issue_url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/issues/23',
#     'number': 23,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump sqlite3 from 2.5.0 to 2.7.3',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Bumps [sqlite3](https://github.com/sparklemotion/sqlite3-ruby) from 2.5.0 to 2.7.3.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/sparklemotion/sqlite3-ruby/releases">sqlite3\'s releases</a>.</em></p>\n<blockquote>\n<h2>2.7.3 / 2025-07-18</h2>\n<ul>\n<li>Vendored sqlite is updated to <a href="https://sqlite.org/releaselog/3_50_3.html">v3.50.3</a> (from v3.50.2). <a href="https://redirect.github.com/sparklemotion/sqlite3-ruby/issues/638">#638</a> <a href="https://github.com/flavorjones"><code>@\u200bflavorjones</code></a></li>\n</ul>\n<!-- raw HTML omitted -->\n<pre><code>00bab7e2ceb7e911b0a2c516bcb9ec0aa7ee57b9b231419e1788515319ac4317  sqlite3-2.7.3-aarch64-linux-gnu.gem\n035dca6c5bc0f45bb059f33cf774e96462563e460a2d5bd48972562bf3a78c8b  sqlite3-2.7.3-aarch64-linux-musl.gem\n133772f4312a9d0fa0c16aab7c2abdda2ee93f47dded0f353a2981f7b9d2b9b4  sqlite3-2.7.3-arm64-darwin.gem\nc22a2593a8274cba5fc55be415cfddab3ff5d3275b5a78878daf214bf2a60db1  sqlite3-2.7.3-arm-linux-gnu.gem\ne735bea1c81eceff2e1b3388e6bccbcbf5c81405f7dbd69b5c80b3b4c4a92c89  sqlite3-2.7.3-arm-linux-musl.gem\nd2b2fecd9341132f2cea3fde9061ee0fab9c9d532a8ecccfab4fe63d9621bf57  sqlite3-2.7.3.gem\nd002ba2c321b9e0ee276090fb7009102c5fbe21abd41a05164e2239e6fd33b4a  sqlite3-2.7.3-x64-mingw-ucrt.gem\na857e364e858d79e634c66c02c130f79c633f0035d422b3381be9958859771f4  sqlite3-2.7.3-x86_64-darwin.gem\n11b2612fddf56602d238be7a984fa0633e591edd034f7520747bc0927b7fa865  sqlite3-2.7.3-x86_64-linux-gnu.gem\n4307278661bbe0a619da7a5da25f4417f6826246ee7b4a56a5c10c3731d5256a  sqlite3-2.7.3-x86_64-linux-musl.gem\n542d713070e222524acd902c67eda71cda4a2b2118164a7b9be4ff4dc3c7ef8e  sqlite3-2.7.3-x86-linux-gnu.gem\na6ccb9e3bb4f4e60f04f7f003be28f1b626b4f153ba6d37afc464cf65d029c89  sqlite3-2.7.3-x86-linux-musl.gem\n</code></pre>\n<!-- raw HTML omitted -->\n<h2>2.7.2 / 2025-07-05</h2>\n<ul>\n<li>Backport a <a href="https://sqlite.org/src/info/64f5f14322">fix</a> to the vendored SQLite to support compilation on Rocky Linux. See the <a href="https://sqlite.org/forum/forumpost/44a58c8073">SQLite forum post</a> for more details. <a href="https://redirect.github.com/sparklemotion/sqlite3-ruby/issues/634">#634</a>, <a href="https://redirect.github.com/sparklemotion/sqlite3-ruby/issues/635">#635</a> <a href="https://github.com/flavorjones"><code>@\u200bflavorjones</code></a></li>\n</ul>\n<!-- raw HTML omitted -->\n<pre><code>b1688e8661c65f65bb16a9879c8171c94d22322f4d8e9e452f396a3aa55bbe0a  sqlite3-2.7.2-aarch64-linux-gnu.gem\n9086f9370853825c5bbb4d1156c9b1494a7ab5052445469603de5a4f2d127ef1  sqlite3-2.7.2-aarch64-linux-musl.gem\ne09a781a69d793424864cac99daa17a24308fcda1dc459a94ef25ecf31082b60  sqlite3-2.7.2-arm64-darwin.gem\nf31d361744775942c4ef7f645457736ad7cdc1c5128a6c19551753e969ccc9be  sqlite3-2.7.2-arm-linux-gnu.gem\n0dc0c1b06c0af0e8833508f212297f8665bf37ea624739fdde30d9adba015f20  sqlite3-2.7.2-arm-linux-musl.gem\n446376dfc5ffa0c6dd39dabf748b8c7c8a7f294cfa780dfc22dee67d43bdc9f5  sqlite3-2.7.2.gem\n7132a85f0d6497ffb77b97070169d51a51639c890731008d2213cc883150a845  sqlite3-2.7.2-x64-mingw-ucrt.gem\n92229c8de5a63a3ed909c6390d187439adeeb614700eed30cf19a4f11c3af370  sqlite3-2.7.2-x86_64-darwin.gem\ne15e8b1224e47a8fec2833afcc6c727742eab6a470c929a54551ab03d04dd4a4  sqlite3-2.7.2-x86_64-linux-gnu.gem\n1f7e386b82a78c24ef9f875b4891bcee51d1c2cd254f028b3ce3dd429605bc35  sqlite3-2.7.2-x86_64-linux-musl.gem\ne6ea2f0186a17655b6aefa24d0b97b5989a47b73466bb7c93ec4ed4ee08ef7b7  sqlite3-2.7.2-x86-linux-gnu.gem\n932c8f8d36f90c0a148391f8e5b694be175c15bbac738dd21c79dbc5fbe5f5ab  sqlite3-2.7.2-x86-linux-musl.gem\n</code></pre>\n<!-- raw HTML omitted -->\n<h2>2.7.1 / 2025-06-30</h2>\n<ul>\n<li>Vendored sqlite is updated to <a href="https://sqlite.org/releaselog/3_50_2.html">v3.50.2</a> (from v3.50.1). <a href="https://redirect.github.com/sparklemotion/sqlite3-ruby/issues/633">#633</a> <a href="https://github.com/flavorjones"><code>@\u200bflavorjones</code></a></li>\n</ul ...
#     'created_at': '2025-07-22T09:42:47Z',
#     'updated_at': '2025-07-22T09:42:48Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 8056360150,
#       'node_id': 'LA_kwDONvtwzM8AAAAB4DJM1g',
#       'url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 8056360165,
#       'node_id': 'LA_kwDONvtwzM8AAAAB4DJM5Q',
#       'url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/labels/ruby',
#       'name': 'ruby',
#       'color': 'ce2d2d',
#       'default': False,
#       'description': 'Pull requests that update Ruby code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/pulls/23/commits',
#     'review_comments_url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/pulls/23/comments',
#     'review_comment_url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/issues/23/comments',
#     'statuses_url': 'https://api.github.com/repos/SakshiPharande/PawsAndAdopt/statuses/3987456fd642f16d0bf086678cee26a437c10df9',
# ...
#       'subscribers_url': 'https://api.github.com/repos/mochilang/mochi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mochilang/mochi/subscription',
#       'commits_url': 'https://api.github.com/repos/mochilang/mochi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mochilang/mochi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mochilang/mochi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mochilang/mochi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mochilang/mochi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mochilang/mochi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mochilang/mochi/merges',
#       'archive_url': 'https://api.github.com/repos/mochilang/mochi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mochilang/mochi/downloads',
#       'issues_url': 'https://api.github.com/repos/mochilang/mochi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mochilang/mochi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mochilang/mochi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mochilang/mochi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mochilang/mochi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mochilang/mochi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mochilang/mochi/deployments',
#       'created_at': '2025-05-18T16:56:07Z',
#       'updated_at': '2025-07-22T09:38:51Z',
#       'pushed_at': '2025-07-22T09:42:47Z',
#       'git_url': 'git://github.com/mochilang/mochi.git',
#       'ssh_url': 'git@github.com:mochilang/mochi.git',
#       'clone_url': 'https://github.com/mochilang/mochi.git',
#       'svn_url': 'https://github.com/mochilang/mochi',
#       'homepage': '',
#       'size': 71016,
#       'stargazers_count': 302,
#       'watchers_count': 302,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 13,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 130,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['agent', 'ai', 'graph', 'leetcode', 'stream'],
#       'visibility': 'public',
#       'forks': 13,
#       'open_issues': 130,
#       'watchers': 302,
#       'default_branch': 'main'}},
#     'base': {'label': 'mochilang:main',
#      'ref': 'main',
#      'sha': '84ef1aed805611536a2f2d44ae7af64ead6181c0',
#      'user': {'login': 'mochilang',
#       'id': 212254672,
#       'node_id': 'O_kgDODKa_0A',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/212254672?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mochilang',
#       'html_url': 'https://github.com/mochilang',
#       'followers_url': 'https://api.github.com/users/mochilang/followers',
#       'following_url': 'https://api.github.com/users/mochilang/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mochilang/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mochilang/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mochilang/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mochilang/orgs',
#       'repos_url': 'https://api.github.com/users/mochilang/repos',
#       'events_url': 'https://api.github.com/users/mochilang/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mochilang/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 985853139,
#       'node_id': 'R_kgDOOsLs0w',
#       'name': 'mochi',
#       'full_name': 'mochilang/mochi',
#       'private': False,
#       'owner': {'login': 'mochilang',
#        'id': 212254672,
#        'node_id': 'O_kgDODKa_0A',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/212254672?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mochilang',
#        'html_url': 'https://github.com/mochilang',
#        'followers_url': 'https://api.github.com/users/mochilang/followers',
#        'following_url': 'https://api.github.com/users/mochilang/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mochilang/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mochilang/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mochilang/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mochilang/orgs',
#        'repos_url': 'https://api.github.com/users/mochilang/repos',
#        'events_url': 'https://api.github.com/users/mochilang/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mochilang/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/mochilang/mochi',
#       'description': 'Mochi is a small, fast, embeddable programming language designed for agents, data, and AI. It combines functional syntax, stream-first semantics, and native support for datasets, graphs, and simulation.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mochilang/mochi',
#       'forks_url': 'https://api.github.com/repos/mochilang/mochi/forks',
#       'keys_url': 'https://api.github.com/repos/mochilang/mochi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mochilang/mochi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mochilang/mochi/teams',
#       'hooks_url': 'https://api.github.com/repos/mochilang/mochi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mochilang/mochi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mochilang/mochi/events',
#       'assignees_url': 'https://api.github.com/repos/mochilang/mochi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mochilang/mochi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mochilang/mochi/tags',
#       'blobs_url': 'https://api.github.com/repos/mochilang/mochi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mochilang/mochi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mochilang/mochi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mochilang/mochi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mochilang/mochi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mochilang/mochi/languages',
#       'stargazers_url': 'https://api.github.com/repos/mochilang/mochi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mochilang/mochi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mochilang/mochi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mochilang/mochi/subscription',
#       'commits_url': 'https://api.github.com/repos/mochilang/mochi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mochilang/mochi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mochilang/mochi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mochilang/mochi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mochilang/mochi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mochilang/mochi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mochilang/mochi/merges',
#       'archive_url': 'https://api.github.com/repos/mochilang/mochi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mochilang/mochi/downloads',
#       'issues_url': 'https://api.github.com/repos/mochilang/mochi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mochilang/mochi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mochilang/mochi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mochilang/mochi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mochilang/mochi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mochilang/mochi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mochilang/mochi/deployments',
#       'created_at': '2025-05-18T16:56:07Z',
#       'updated_at': '2025-07-22T09:38:51Z',
#       'pushed_at': '2025-07-22T09:42:47Z',
#       'git_url': 'git://github.com/mochilang/mochi.git',
#       'ssh_url': 'git@github.com:mochilang/mochi.git',
#       'clone_url': 'https://github.com/mochilang/mochi.git',
#       'svn_url': 'https://github.com/mochilang/mochi',
#       'homepage': '',
#       'size': 71016,
#       'stargazers_count': 302,
#       'watchers_count': 302,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 13,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 130,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['agent', 'ai', 'graph', 'leetcode', 'stream'],
#       'visibility': 'public',
#       'forks': 13,
#       'open_issues': 130,
#       'watchers': 302,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mochilang/mochi/pulls/11871'},
#      'html': {'href': 'https://github.com/mochilang/mochi/pull/11871'},
#      'issue': {'href': 'https://api.github.com/repos/mochilang/mochi/issues/11871'},
#      'comments': {'href': 'https://api.github.com/repos/mochilang/mochi/issues/11871/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mochilang/mochi/pulls/11871/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mochilang/mochi/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mochilang/mochi/pulls/11871/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mochilang/mochi/statuses/451f10204bcbd463f7ec6d0842f72cfb4930ccfe'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 168,
#     'deletions': 20,
#     'changed_files': 9}},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 212254672,
#    'login': 'mochilang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mochilang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/212254672?'}},
#  {'id': '52383566721',
#   'type': 'PushEvent',
#   'actor': {'id': 191582904,
#    'login': 'DrXSolutions9',
#    'display_login': 'DrXSolutions9',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DrXSolutions9',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/191582904?'},
#   'repo': {'id': 902816992,
#    'name': 'DrXSolutions9/Image-Dr.X-Solution-9',
#    'url': 'https://api.github.com/repos/DrXSolutions9/Image-Dr.X-Solution-9'},
#   'payload': {'repository_id': 902816992,
#    'push_id': 25646457107,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a74177fe194aaecfaadfae442a9cf1e5a9966ef0',
#    'before': '8b951ec633d0cba14aadb71b81aced50a7fb9900',
#    'commits': [{'sha': 'a74177fe194aaecfaadfae442a9cf1e5a9966ef0',
#      'author': {'email': 'drx.aesthetic@gmail.com', 'name': 'Dr.x Solution'},
#      'message': 'upload 01983183-970a-71c8-b996-b10105aa3a5b',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DrXSolutions9/Image-Dr.X-Solution-9/commits/a74177fe194aaecfaadfae442a9cf1e5a9966ef0'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566731',
#   'type': 'PushEvent',
#   'actor': {'id': 204667811,
#    'login': 'Ethanzhao-1',
#    'display_login': 'Ethanzhao-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ethanzhao-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/204667811?'},
#   'repo': {'id': 1023513572,
#    'name': 'Ethanzhao-1/zhaoyiran',
#    'url': 'https://api.github.com/repos/Ethanzhao-1/zhaoyiran'},
#   'payload': {'repository_id': 1023513572,
#    'push_id': 25646457105,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9491247c40fa8b350ea01eeabf9dc3d1d41ffc64',
#    'before': '78df49bde325d89a09f44ce621eed72d9da0809c',
#    'commits': [{'sha': '9491247c40fa8b350ea01eeabf9dc3d1d41ffc64',
#      'author': {'email': 'zhaoyiran201125@gmail.com', 'name': 'Ethanzhao-1'},
#      'message': 'Update style.css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ethanzhao-1/zhaoyiran/commits/9491247c40fa8b350ea01eeabf9dc3d1d41ffc64'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566695',
#   'type': 'PushEvent',
#   'actor': {'id': 33210710,
#    'login': 'tfolkersen',
#    'display_login': 'tfolkersen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tfolkersen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33210710?'},
#   'repo': {'id': 835848854,
#    'name': 'ualberta-mueller-group/MCGS',
#    'url': 'https://api.github.com/repos/ualberta-mueller-group/MCGS'},
#   'payload': {'repository_id': 835848854,
#    'push_id': 25646457006,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/v1.3-develop',
#    'head': 'e6729b091d2515e493f535215f10ba7fc9778f48',
#    'before': 'bb4b1b4fb79552013259a95b0c41c26d4daa0bcc',
#    'commits': [{'sha': 'e6729b091d2515e493f535215f10ba7fc9778f48',
#      'author': {'email': 'folkerse@ualberta.ca', 'name': 'tfolkersen'},
#      'message': 'refactor',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ualberta-mueller-group/MCGS/commits/e6729b091d2515e493f535215f10ba7fc9778f48'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 78824564,
#    'login': 'ualberta-mueller-group',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ualberta-mueller-group',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78824564?'}},
#  {'id': '52383566689',
#   'type': 'PushEvent',
#   'actor': {'id': 25336974,
#    'login': 'anpandey',
#    'display_login': 'anpandey',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anpandey',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25336974?'},
#   'repo': {'id': 1013738401,
#    'name': 'anpandey/lily58-wireless-zmk-config',
#    'url': 'https://api.github.com/repos/anpandey/lily58-wireless-zmk-config'},
#   'payload': {'repository_id': 1013738401,
#    'push_id': 25646457077,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8251f76a328cef7db8a3ab182a11f4361ecbf117',
#    'before': 'ecdd03130a26d75ee0303c50b23c2d906489c89a',
#    'commits': [{'sha': '8251f76a328cef7db8a3ab182a11f4361ecbf117',
#      'author': {'email': 'anpandey@pm.me', 'name': 'Ankit Pandey'},
#      'message': 'Make press and release explicit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/anpandey/lily58-wireless-zmk-config/commits/8251f76a328cef7db8a3ab182a11f4361ecbf117'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'}]

# %% [markdown]
# Looks like some data, cool, let's examine what this website actually is and how this json output relates to the website's information.

# %%
example_request.url
# Out:
# 'https://api.github.com/events'

# %% [markdown]
# The website is something wierd, not a normal website, so I will use Geeksforgeeks example

# %% [markdown]
# All the websites there are also wierd... hmmm.... I think I need now ChatGPT, this is getting impossible!

# %% [markdown]
# The regular websites don't look that way. So how to connect to them?

# %% [markdown]
# So I think there is fundamentally something going on that I don't know yet, but for simplicity, I will not dig into that part, but go on with the youtube.com, because this is what I need to do. I ask ChatGPT, how to .... perhaps that each website has to have some sort of API-tunnel to get through, and just grabbing data from a website is not necessarily api but maybe some other technical word, I Don't know... we'll see

# %% [markdown]
# Actually, not youtube, I check astronomy and api.

# %% [markdown]
# So, the first few results in google search for "astronomy api" bring the following websites:

# %% [markdown]
# Remember, I am trying to bring it home to something tangilbe that I can understand
#
# 'Astronomy API' google search top results, wow:
# https://api.nasa.gov/
# https://docs.astronomyapi.com/
# https://dev.timeanddate.com/astro/
# https://github.com/astrocatalogs/OACAPI
# https://ipgeolocation.io/astronomy-api.html
# https://rapidapi.com/astronomyapi-astronomyapi-default/api/astronomy
#
# It appears to use json, I need to do something extro on my website, otherwise, I can get with requests package the status update etc., but not json stuff...
#
# I don't want to be building more staff on my website at this moment, maybe I can use a NASA api example, let's see if json works there

# %%
nasa_url = 'https://api.nasa.gov/'
nasa_request = requests.get(nasa_url)

# %%
data_nasa = nasa_request.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/opt/anaconda3/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# File ~/opt/anaconda3/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/opt/anaconda3/lib/python3.8/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 data_nasa = nasa_request.json()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# With the help of ChatGPT, I found out that for json you need not just an api website, but also actually a particular endpoint-type-website, such as https://images-api.nasa.gov/search

# %%
nasa_endpoint_url = 'https://images-api.nasa.gov/search'
nasa_endpoint_request = requests.get(nasa_endpoint_url)

# %%
nasa_endpoint_request.json()
# Out:
# {'reason': "Expected 'q' text search parameter or other keywords."}

# %% [markdown]
# Okay, now this works, but I have no idea what the reason and expected q and other staff means.... and what I can do with it

# %% [markdown]
# At this point, I am not sure if API is what I needed....

# %%
AGN = data['search']['agn']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 AGN = data['search']['agn']
#
# TypeError: list indices must be integers or slices, not str

# %%
image
# Out:
# [{'id': '52383566977',
#   'type': 'PushEvent',
#   'actor': {'id': 217809078,
#    'login': 'IntisarMustafa',
#    'display_login': 'IntisarMustafa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IntisarMustafa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/217809078?'},
#   'repo': {'id': 1007950965,
#    'name': 'IntisarMustafa/7',
#    'url': 'https://api.github.com/repos/IntisarMustafa/7'},
#   'payload': {'repository_id': 1007950965,
#    'push_id': 25646457200,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1d0317b70801c95b8283cc6925dc579fd2400305',
#    'before': '14f5c3056df8ed4225013887c5beb5e00baed45e',
#    'commits': [{'sha': '1d0317b70801c95b8283cc6925dc579fd2400305',
#      'author': {'email': 'int.mustafa@unrwa.org', 'name': 'IntisarMustafa'},
#      'message': 'Update u2l2p5.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IntisarMustafa/7/commits/1d0317b70801c95b8283cc6925dc579fd2400305'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566988',
#   'type': 'CreateEvent',
#   'actor': {'id': 204291824,
#    'login': 'frostyxsec',
#    'display_login': 'frostyxsec',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/frostyxsec',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/204291824?'},
#   'repo': {'id': 1024167614,
#    'name': 'frostyxsec/RyuuGuard',
#    'url': 'https://api.github.com/repos/frostyxsec/RyuuGuard'},
#   'payload': {'ref': 'release',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': 'Simple OpenSource IDSA in server engine with live notification',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566914',
#   'type': 'PushEvent',
#   'actor': {'id': 51156018,
#    'login': 'ianjon3s',
#    'display_login': 'ianjon3s',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ianjon3s',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51156018?'},
#   'repo': {'id': 282647716,
#    'name': 'theopensystemslab/planx-new',
#    'url': 'https://api.github.com/repos/theopensystemslab/planx-new'},
#   'payload': {'repository_id': 282647716,
#    'push_id': 25646457143,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ian/lps-empty-applications-page',
#    'head': '836364e30bed7eb930ea41e3f302e285979ad2df',
#    'before': '3e99f6e7ddb59fb637e32740e7d54513b14dd2ca',
#    'commits': [{'sha': '836364e30bed7eb930ea41e3f302e285979ad2df',
#      'author': {'email': 'hello@ianjo.uk', 'name': 'Ian Jones'},
#      'message': 'use styled-content',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/theopensystemslab/planx-new/commits/836364e30bed7eb930ea41e3f302e285979ad2df'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 38584178,
#    'login': 'theopensystemslab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/theopensystemslab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38584178?'}},
#  {'id': '52383566957',
#   'type': 'PushEvent',
#   'actor': {'id': 191581607,
#    'login': 'DrXSolutions6',
#    'display_login': 'DrXSolutions6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DrXSolutions6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/191581607?'},
#   'repo': {'id': 902811413,
#    'name': 'DrXSolutions6/Image-Dr.X-Solution-6',
#    'url': 'https://api.github.com/repos/DrXSolutions6/Image-Dr.X-Solution-6'},
#   'payload': {'repository_id': 902811413,
#    'push_id': 25646457084,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '272d9c7aab5c34727f3052882e515fcc56124b3c',
#    'before': 'c7f81705c253bb285ac82c3bf656e2fd2d46784d',
#    'commits': [{'sha': '272d9c7aab5c34727f3052882e515fcc56124b3c',
#      'author': {'email': 'drx.aesthetic@gmail.com', 'name': 'Dr.x Solution'},
#      'message': 'upload 01983183-986d-7985-9a4f-3a15a8318665',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DrXSolutions6/Image-Dr.X-Solution-6/commits/272d9c7aab5c34727f3052882e515fcc56124b3c'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566884',
#   'type': 'PushEvent',
#   'actor': {'id': 106555838,
#    'login': 'AbdulTheActivePiecer',
#    'display_login': 'AbdulTheActivePiecer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AbdulTheActivePiecer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106555838?'},
#   'repo': {'id': 573661753,
#    'name': 'activepieces/activepieces',
#    'url': 'https://api.github.com/repos/activepieces/activepieces'},
#   'payload': {'repository_id': 573661753,
#    'push_id': 25646457076,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n_main',
#    'head': '33a04d6a4b116c93854cd62a93cf5fbe1d6fd94f',
#    'before': 'c06995ddb99bfb9313ade3ea51a569030751cf9a',
#    'commits': [{'sha': '33a04d6a4b116c93854cd62a93cf5fbe1d6fd94f',
#      'author': {'email': '106555838+AbdulTheActivePiecer@users.noreply.github.com',
#       'name': 'Abdul'},
#      'message': 'New translations translation.json (Chinese Simplified)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/activepieces/activepieces/commits/33a04d6a4b116c93854cd62a93cf5fbe1d6fd94f'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 99494700,
#    'login': 'activepieces',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/activepieces',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99494700?'}},
#  {'id': '52383566938',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 944642230,
#    'name': 'dperkosan/gateway',
#    'url': 'https://api.github.com/repos/dperkosan/gateway'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/dperkosan/gateway/pulls/3',
#     'id': 2684887974,
#     'node_id': 'PR_kwDOOE4Yts6gCCOm',
#     'html_url': 'https://github.com/dperkosan/gateway/pull/3',
#     'diff_url': 'https://github.com/dperkosan/gateway/pull/3.diff',
#     'patch_url': 'https://github.com/dperkosan/gateway/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/dperkosan/gateway/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump form-data from 4.0.1 to 4.0.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Bumps [form-data](https://github.com/form-data/form-data) from 4.0.1 to 4.0.4.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/form-data/form-data/blob/master/CHANGELOG.md">form-data\'s changelog</a>.</em></p>\n<blockquote>\n<h2><a href="https://github.com/form-data/form-data/compare/v4.0.3...v4.0.4">v4.0.4</a> - 2025-07-16</h2>\n<h3>Commits</h3>\n<ul>\n<li>[meta] add <code>auto-changelog</code> <a href="https://github.com/form-data/form-data/commit/811f68282fab0315209d0e2d1c44b6c32ea0d479"><code>811f682</code></a></li>\n<li>[Tests] handle predict-v8-randomness failures in node &lt; 17 and node &gt; 23 <a href="https://github.com/form-data/form-data/commit/1d11a76434d101f22fdb26b8aef8615f28b98402"><code>1d11a76</code></a></li>\n<li>[Fix] Switch to using <code>crypto</code> random for boundary values <a href="https://github.com/form-data/form-data/commit/3d1723080e6577a66f17f163ecd345a21d8d0fd0"><code>3d17230</code></a></li>\n<li>[Tests] fix linting errors <a href="https://github.com/form-data/form-data/commit/5e340800b5f8914213e4e0378c084aae71cfd73a"><code>5e34080</code></a></li>\n<li>[meta] actually ensure the readme backup isn’t published <a href="https://github.com/form-data/form-data/commit/316c82ba93fd4985af757b771b9a1f26d3b709ef"><code>316c82b</code></a></li>\n<li>[Dev Deps] update <code>@ljharb/eslint-config</code> <a href="https://github.com/form-data/form-data/commit/58c25d76406a5b0dfdf54045cf252563f2bbda8d"><code>58c25d7</code></a></li>\n<li>[meta] fix readme capitalization <a href="https://github.com/form-data/form-data/commit/2300ca19595b0ee96431e868fe2a40db79e41c61"><code>2300ca1</code></a></li>\n</ul>\n<h2><a href="https://github.com/form-data/form-data/compare/v4.0.2...v4.0.3">v4.0.3</a> - 2025-06-05</h2>\n<h3>Fixed</h3>\n<ul>\n<li>[Fix] <code>append</code>: avoid a crash on nullish values <a href="https://redirect.github.com/form-data/form-data/issues/577"><code>[#577](https://github.com/form-data/form-data/issues/577)</code></a></li>\n</ul>\n<h3>Commits</h3>\n<ul>\n<li>[eslint] use a shared config <a href="https://github.com/form-data/form-data/commit/426ba9ac440f95d1998dac9a5cd8d738043b048f"><code>426ba9a</code></a></li>\n<li>[eslint] fix some spacing issues <a href="https://github.com/form-data/form-data/commit/20941917f0e9487e68c564ebc3157e23609e2939"><code>2094191</code></a></li>\n<li>[Refactor] use <code>hasown</code> <a href="https://github.com/form-data/form-data/commit/81ab41b46fdf34f5d89d7ff30b513b0925febfaa"><code>81ab41b</code></a></li>\n<li>[Fix] validate boundary type in <code>setBoundary()</code> method <a href="https://github.com/form-data/form-data/commit/8d8e4693093519f7f18e3c597d1e8df8c493de9e"><code>8d8e469</code></a></li>\n<li>[Tests] add tests to check the behavior of <code>getBoundary</code> with non-strings <a href="https://github.com/form-data/form-data/commit/837b8a1f7562bfb8bda74f3fc538adb7a5858995"><code>837b8a1</code></a></li>\n<li>[Dev Deps] remove unused deps <a href="https://github.com/form-data/form-data/commit/870e4e665935e701bf983a051244ab928e62d58e"><code>870e4e6</code></a></li>\n<li>[meta] remove local commit hooks <a href="https://github.com/form-data/form-data/commit/e6e83ccb545a5619ed6cd04f31d5c2f655eb633e"><code>e6e83cc</code></a></li>\n<li>[Dev Deps] update <code>eslint</code> <a href="https://github.com/form-data/form-data/commit/4066fd6f65992b62fa324a6474a9292a4f88c916"><code>4066fd6</code></a></li>\n<li>[meta] fix scripts to use prepublishOnly <a href="https://github.com/form-data/form-data/commit/c4bbb13c0ef669916657bc129341301b1d331d75"><code>c4bbb13</code></a></li>\n</ul>\n<h2><a href="https://github.com/form-data/form-data/compare/v4.0.1...v4.0.2">v4.0.2</a> - 2025-02-14</h2>\n<h3>Merged</h3>\n<ul>\n<li>[Fix] set\xa0<code>Symbol.toStringTag</code> when\xa0available <a href="https://redirect.github.com/form-data/form-data/pull/573"><code>[#573](https://github.com/form-data/form-data/issues/573)</code></a></li> ...
#     'created_at': '2025-07-22T09:42:47Z',
#     'updated_at': '2025-07-22T09:42:47Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 8258308179,
#       'node_id': 'LA_kwDOOE4Yts8AAAAB7DvIUw',
#       'url': 'https://api.github.com/repos/dperkosan/gateway/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 8535289242,
#       'node_id': 'LA_kwDOOE4Yts8AAAAB_L4tmg',
#       'url': 'https://api.github.com/repos/dperkosan/gateway/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update javascript code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/dperkosan/gateway/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/dperkosan/gateway/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/dperkosan/gateway/statuses/e880b901cb286fcdc2b0c6cb9715a7654a345505',
#     'head': {'label': 'dperkosan:dependabot/npm_and_yarn/form-data-4.0.4',
#      'ref': 'dependabot/npm_and_yarn/form-data-4.0.4',
#      'sha': 'e880b901cb286fcdc2b0c6cb9715a7654a345505',
#      'user': {'login': 'dperkosan',
#       'id': 12428970,
#       'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dperkosan',
#       'html_url': 'https://github.com/dperkosan',
#       'followers_url': 'https://api.github.com/users/dperkosan/followers',
#       'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#       'repos_url': 'https://api.github.com/users/dperkosan/repos',
#       'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 944642230,
#       'node_id': 'R_kgDOOE4Ytg',
#       'name': 'gateway',
#       'full_name': 'dperkosan/gateway',
#       'private': False,
#       'owner': {'login': 'dperkosan',
#        'id': 12428970,
#        'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dperkosan',
#        'html_url': 'https://github.com/dperkosan',
#        'followers_url': 'https://api.github.com/users/dperkosan/followers',
#        'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#        'repos_url': 'https://api.github.com/users/dperkosan/repos',
#        'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/dperkosan/gateway',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/dperkosan/gateway',
#       'forks_url': 'https://api.github.com/repos/dperkosan/gateway/forks',
#       'keys_url': 'https://api.github.com/repos/dperkosan/gateway/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dperkosan/gateway/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dperkosan/gateway/teams',
#       'hooks_url': 'https://api.github.com/repos/dperkosan/gateway/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dperkosan/gateway/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dperkosan/gateway/events',
#       'assignees_url': 'https://api.github.com/repos/dperkosan/gateway/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dperkosan/gateway/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dperkosan/gateway/tags',
#       'blobs_url': 'https://api.github.com/repos/dperkosan/gateway/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dperkosan/gateway/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dperkosan/gateway/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dperkosan/gateway/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dperkosan/gateway/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dperkosan/gateway/languages',
#       'stargazers_url': 'https://api.github.com/repos/dperkosan/gateway/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dperkosan/gateway/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dperkosan/gateway/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dperkosan/gateway/subscription',
#       'commits_url': 'https://api.github.com/repos/dperkosan/gateway/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dperkosan/gateway/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dperkosan/gateway/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dperkosan/gateway/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dperkosan/gateway/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dperkosan/gateway/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dperkosan/gateway/merges',
#       'archive_url': 'https://api.github.com/repos/dperkosan/gateway/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dperkosan/gateway/downloads',
#       'issues_url': 'https://api.github.com/repos/dperkosan/gateway/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dperkosan/gateway/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dperkosan/gateway/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dperkosan/gateway/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dperkosan/gateway/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dperkosan/gateway/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dperkosan/gateway/deployments',
#       'created_at': '2025-03-07T17:54:16Z',
#       'updated_at': '2025-03-09T13:32:21Z',
#       'pushed_at': '2025-07-22T09:42:47Z',
#       'git_url': 'git://github.com/dperkosan/gateway.git',
#       'ssh_url': 'git@github.com:dperkosan/gateway.git',
#       'clone_url': 'https://github.com/dperkosan/gateway.git',
#       'svn_url': 'https://github.com/dperkosan/gateway',
#       'homepage': None,
#       'size': 242,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'dperkosan:main',
#      'ref': 'main',
#      'sha': '2dfa6433b12e7105b9c34af6eb7ff5beeda81e6f',
#      'user': {'login': 'dperkosan',
#       'id': 12428970,
#       'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dperkosan',
#       'html_url': 'https://github.com/dperkosan',
#       'followers_url': 'https://api.github.com/users/dperkosan/followers',
#       'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#       'repos_url': 'https://api.github.com/users/dperkosan/repos',
#       'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 944642230,
#       'node_id': 'R_kgDOOE4Ytg',
#       'name': 'gateway',
#       'full_name': 'dperkosan/gateway',
#       'private': False,
#       'owner': {'login': 'dperkosan',
#        'id': 12428970,
#        'node_id': 'MDQ6VXNlcjEyNDI4OTcw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12428970?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dperkosan',
#        'html_url': 'https://github.com/dperkosan',
#        'followers_url': 'https://api.github.com/users/dperkosan/followers',
#        'following_url': 'https://api.github.com/users/dperkosan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dperkosan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dperkosan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dperkosan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dperkosan/orgs',
#        'repos_url': 'https://api.github.com/users/dperkosan/repos',
#        'events_url': 'https://api.github.com/users/dperkosan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dperkosan/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/dperkosan/gateway',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/dperkosan/gateway',
#       'forks_url': 'https://api.github.com/repos/dperkosan/gateway/forks',
#       'keys_url': 'https://api.github.com/repos/dperkosan/gateway/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dperkosan/gateway/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dperkosan/gateway/teams',
#       'hooks_url': 'https://api.github.com/repos/dperkosan/gateway/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dperkosan/gateway/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dperkosan/gateway/events',
#       'assignees_url': 'https://api.github.com/repos/dperkosan/gateway/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dperkosan/gateway/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dperkosan/gateway/tags',
#       'blobs_url': 'https://api.github.com/repos/dperkosan/gateway/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dperkosan/gateway/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dperkosan/gateway/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dperkosan/gateway/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dperkosan/gateway/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dperkosan/gateway/languages',
#       'stargazers_url': 'https://api.github.com/repos/dperkosan/gateway/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dperkosan/gateway/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dperkosan/gateway/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dperkosan/gateway/subscription',
#       'commits_url': 'https://api.github.com/repos/dperkosan/gateway/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dperkosan/gateway/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dperkosan/gateway/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dperkosan/gateway/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dperkosan/gateway/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dperkosan/gateway/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dperkosan/gateway/merges',
#       'archive_url': 'https://api.github.com/repos/dperkosan/gateway/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dperkosan/gateway/downloads',
#       'issues_url': 'https://api.github.com/repos/dperkosan/gateway/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dperkosan/gateway/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dperkosan/gateway/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dperkosan/gateway/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dperkosan/gateway/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dperkosan/gateway/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dperkosan/gateway/deployments',
#       'created_at': '2025-03-07T17:54:16Z',
#       'updated_at': '2025-03-09T13:32:21Z',
#       'pushed_at': '2025-07-22T09:42:47Z',
#       'git_url': 'git://github.com/dperkosan/gateway.git',
#       'ssh_url': 'git@github.com:dperkosan/gateway.git',
#       'clone_url': 'https://github.com/dperkosan/gateway.git',
#       'svn_url': 'https://github.com/dperkosan/gateway',
#       'homepage': None,
#       'size': 242,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/3'},
#      'html': {'href': 'https://github.com/dperkosan/gateway/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/dperkosan/gateway/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/dperkosan/gateway/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/dperkosan/gateway/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/dperkosan/gateway/statuses/e880b901cb286fcdc2b0c6cb9715a7654a345505'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 35,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566861',
#   'type': 'PushEvent',
#   'actor': {'id': 125531081,
#    'login': 'quyk67uet',
#    'display_login': 'quyk67uet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/quyk67uet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125531081?'},
#   'repo': {'id': 1021545392,
#    'name': 'quyk67uet/mmqa_chatbot',
#    'url': 'https://api.github.com/repos/quyk67uet/mmqa_chatbot'},
#   'payload': {'repository_id': 1021545392,
#    'push_id': 25646457174,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ab0cfbcdad55aba532290f4783dd215d2be3084a',
#    'before': 'dd664ce82b3049ed243a6b5262b7e338774fb6f5',
#    'commits': [{'sha': 'ab0cfbcdad55aba532290f4783dd215d2be3084a',
#      'author': {'email': '22028190@vnu.edu.vn', 'name': 'quyk67uet'},
#      'message': 'Update 80',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quyk67uet/mmqa_chatbot/commits/ab0cfbcdad55aba532290f4783dd215d2be3084a'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'},
#  {'id': '52383566901',
#   'type': 'PushEvent',
#   'actor': {'id': 117032989,
#    'login': 'ky1nonly',
#    'display_login': 'ky1nonly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ky1nonly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117032989?'},
#   'repo': {'id': 1015288837,
#    'name': 'prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE',
#    'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE'},
#   'payload': {'repository_id': 1015288837,
#    'push_id': 25646457190,
#    'size': 55,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Feat/75-delete-branch',
#    'head': 'd8aed8b6368d8803ee74eeaa448c918ff0a0472f',
#    'before': 'e06b68b6b7b72886b1e5e54cf1d5e0651409525c',
#    'commits': [{'sha': 'a39e84416aff6f1024de417edc33ce8784575c52',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Feat: 기록 병합하기 API 구현',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/a39e84416aff6f1024de417edc33ce8784575c52'},
#     {'sha': '942140d782f1d089b5b74f2b700c18611146e429',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Fix: TransactionManager 적용 전 상태이므로 해당 코드 주석처리 & ToDo 작성',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/942140d782f1d089b5b74f2b700c18611146e429'},
#     {'sha': 'a27c9469722d4f4af0c11a9d3bac0aee2ec5f251',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Refactor: 트랜잭션 처리 방식 변경',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/a27c9469722d4f4af0c11a9d3bac0aee2ec5f251'},
#     {'sha': '61a88579482ce76e27fe38a630d6108b73f8d1c1',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Chore: Swagger 의존성 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/61a88579482ce76e27fe38a630d6108b73f8d1c1'},
#     {'sha': 'c4485e0fe1dbf09429a7aaf32c3ae3275ccea42f',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Chore: Swagger 관련 경로 인증 없이 접근 가능하도록 설정',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/c4485e0fe1dbf09429a7aaf32c3ae3275ccea42f'},
#     {'sha': '1ec30c932dc881c123af00d1beec97b0ba6f8a95',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: DocsaApplication에 Swagger OpenAPI 메타 정보 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/1ec30c932dc881c123af00d1beec97b0ba6f8a95'},
#     {'sha': 'e9b8ca226f6018719765be5ae807b135d410f7c8',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: AuthController Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/e9b8ca226f6018719765be5ae807b135d410f7c8'},
#     {'sha': 'dfddd13722d9c9554ac4d2626e5c3921bd36f483',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: Auth DTO Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/dfddd13722d9c9554ac4d2626e5c3921bd36f483'},
#     {'sha': '67887b1006ca49359947cbd7e7496eb1721b7c8d',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: UserController Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/67887b1006ca49359947cbd7e7496eb1721b7c8d'},
#     {'sha': 'f33c5b5e430f487637adcc9d0d6d84f1bec1fcf0',
#      'author': {'email': 'wjdals20309@naver.com', 'name': 'Jeongmin39'},
#      'message': 'Docs: User DTO Swagger 어노테이션 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/f33c5b5e430f487637adcc9d0d6d84f1bec1fcf0'},
#     {'sha': '2c9d0227ee97da3effc19f737d58f49877eb0ff6',
#      'author': {'email': '80705450+Jeongmin39@users.noreply.github.com',
#       'name': '한정민'},
#      'message': "Merge branch 'dev' into Docs/80-swagger-auth-user",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/2c9d0227ee97da3effc19f737d58f49877eb0ff6'},
#     {'sha': 'a0acf16ad55879bb6cb3fd2fac4f10be5f168ac6',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : swagger 도입중',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/a0acf16ad55879bb6cb3fd2fac4f10be5f168ac6'},
#     {'sha': '1b0da6f889643f9bd2006ee1fd41d3456b2da5cf',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : swagger url 권한 허용',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/1b0da6f889643f9bd2006ee1fd41d3456b2da5cf'},
#     {'sha': '363e0441cf445bcec9e61f550983dcbc5ae7d028',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Fix: Edge 엔티티의 연관관계 수정',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/363e0441cf445bcec9e61f550983dcbc5ae7d028'},
#     {'sha': '694ff3b733bfe9e7c4ed22af4e74e5050001ff31',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : Save 도메인 1차 스웨거 (구체적인 응답 없음)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/694ff3b733bfe9e7c4ed22af4e74e5050001ff31'},
#     {'sha': '8921625da79d73d147c84a16079efef14481d23d',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Fix: Branch 엔티티의 연관관계 속성 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/8921625da79d73d147c84a16079efef14481d23d'},
#     {'sha': '59969a22dd2f781406355fb285af00b05f2db80c',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': "Merge branch 'dev' into Docs/83-save-swagger",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/59969a22dd2f781406355fb285af00b05f2db80c'},
#     {'sha': 'bdd063a78088052086a4485a5181d68d408ef57c',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Feat: BaseBranch와 TargetBranch가 일치하는지 검사하는 로직 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/bdd063a78088052086a4485a5181d68d408ef57c'},
#     {'sha': '787c2306fc48a757b3a25d297bf43741a99cf9e5',
#      'author': {'email': 'ddft97@gmail.com', 'name': '2ternal'},
#      'message': 'Test: Merge Commit에 대한 통합테스트',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/787c2306fc48a757b3a25d297bf43741a99cf9e5'},
#     {'sha': '96638c5f308e29e6d2a992809c2598b2b15d4194',
#      'author': {'email': 'pokjm99@naver.com', 'name': 'sleepyhoon'},
#      'message': 'Feat : Save 도메인 디테일 응답 추가',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/prgrms-web-devcourse-final-project/WEB5_7_2Jangs_BE/commits/96638c5f308e29e6d2a992809c2598b2b15d4194'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z',
#   'org': {'id': 187719732,
#    'login': 'prgrms-web-devcourse-final-project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/prgrms-web-devcourse-final-project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/187719732?'}},
#  {'id': '52383566826',
#   'type': 'PushEvent',
#   'actor': {'id': 173871145,
#    'login': 'rajarshi1912',
#    'display_login': 'rajarshi1912',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rajarshi1912',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/173871145?'},
#   'repo': {'id': 1006877878,
#    'name': 'rajarshi1912/agrowin_module',
#    'url': 'https://api.github.com/repos/rajarshi1912/agrowin_module'},
#   'payload': {'repository_id': 1006877878,
#    'push_id': 25646457157,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/NP',
#    'head': '14ecdbc0de0e31557d0465e9cc84f8ea5acdefb9',
#    'before': 'df91685cdc8f44bf212a3f49d5bb47cb318ca999',
#    'commits': [{'sha': '14ecdbc0de0e31557d0465e9cc84f8ea5acdefb9',
#      'author': {'email': 'rajarshi.chakraborty.ext@bayer.com',
#       'name': 'rajarshi1912'},
#      'message': 'Update fungi_mapping.sql',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rajarshi1912/agrowin_module/commits/14ecdbc0de0e31557d0465e9cc84f8ea5acdefb9'}]},
#   'public': True,
#   'created_at': '2025-07-22T09:42:49Z'}]

# %% [markdown]
# # I am getting confused how to use this json thing with api and with all of it, for example if I want to retrieve an image or something about the images of NASA...

# %% [markdown]
# Chatting with ChatGPT, I see that there is documentation and certain parameters can be used for the searching of the images

# %%
#let's try again

parameters = {
                'media_type':'image',
                'q':'AGN'                
                }

nasa_image_search_request = requests.get(nasa_endpoint_url, params=parameters) # I am specifying parameters


#Here how to write the parameters
#https://requests.readthedocs.io/en/latest/user/quickstart/#passing-parameters-in-urls
#https://images.nasa.gov/docs/images.nasa.gov_api_docs.pdf

# %%
nasa_image_search_request.url
# Out:
# 'https://images-api.nasa.gov/search?media_type=image&q=AGN'

# %% [markdown]
# # So this is what I searched... This is so wierd, not sure where it is going exactly at this point. So can I get somehow one image or info about one image?

# %%
nasa_image_search_data = nasa_image_search_request.json()

# %%
nasa_image_search_data
# Out:
# {'collection': {'version': '1.1',
#   'href': 'http://images-api.nasa.gov/search?media_type=image&q=AGN',
#   'items': [{'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/collection.json',
#     'data': [{'center': 'GSFC',
#       'date_created': '2015-10-12T00:00:00Z',
#       'description': 'NGC 4639 is a beautiful example of a type of galaxy known as a barred spiral. It lies over 70 million light-years away in the constellation of\xa0Virgo and is one of about 1500 galaxies that make up the Virgo Cluster. In this image, taken by the NASA/ESA Hubble Space Telescope, one can clearly see the bar running through the bright, round core of the galaxy. Bars are found in around two thirds of spiral galaxies, and are thought to be a natural phase in their evolution. The galaxy’s spiral arms are sprinkled with bright regions of active star formation. Each of these tiny jewels is actually several hundred light-years across and contains hundreds or thousands of newly formed stars. But NGC 4639 also conceals a dark secret in its core — a massive black hole that is consuming the surrounding gas. This is known as an active galactic nucleus (AGN), and is revealed by characteristic features in the spectrum of light from the galaxy and by\xa0X-rays produced close to the black hole as the hot gas plunges towards it. Most galaxies are thought to contain a black hole at the centre. NGC 4639 is in fact a very weak example of an AGN, demonstrating that AGNs exist over a large range of activity, from galaxies like NGC 4639 to distant quasars, where the parent galaxy is almost completely dominated by the emissions from the AGN.',
#       'keywords': ['NGC 4639'],
#       'media_type': 'image',
#       'nasa_id': 'hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o',
#       'title': 'Elegant spiral hides a hungry monster'}],
#     'links': [{'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~medium.jpg',
#       'rel': 'alternate',
#       'render': 'image',
#       'width': 1222,
#       'size': 213000,
#       'height': 1280},
#      {'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~small.jpg',
#       'rel': 'alternate',
#       'render': 'image',
#       'width': 611,
#       'size': 42000,
#       'height': 640},
#      {'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~thumb.jpg',
#       'rel': 'preview',
#       'render': 'image',
#       'width': 611,
#       'size': 42000,
#       'height': 640},
#      {'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~orig.jpg',
#       'rel': 'canonical',
#       'render': 'image',
#       'height': 1340,
#       'width': 1280,
#       'size': 407000}]},
#    {'href': 'https://images-assets.nasa.gov/image/GSFC_20171208_Archive_e000539/collection.json',
#     'data': [{'album': ['Test'],
#       'center': 'GSFC',
#       'date_created': '2017-12-08T00:00:00Z',
#       'description': 'NGC 4639 is a beautiful example of a type of galaxy known as a barred spiral. It lies over 70 million light-years away in the constellation of Virgo and is one of about 1,500 galaxies that make up the Virgo Cluster.  In this image, taken by the NASA/ESA Hubble Space Telescope, one can clearly see the bar running through the bright, round core of the galaxy. Bars are found in around two-thirds of spiral galaxies, and are thought to be a natural phase in their evolution.  The galaxy’s spiral arms are sprinkled with bright regions of active star formation. Each of these tiny jewels is actually several hundred light-years across and contains hundreds or thousands of newly formed stars. But NGC 4639 also conceals a dark secret in its core — a massive black hole that is consuming the surrounding gas.  This is known as an active galactic nucleus (AGN), and is revealed by characteristic features in the spectrum of light from the galaxy and by X-rays produced close to the black hole as the hot gas plunges towards it.  Most galaxies are thought to contain a black hole at the center. NGC 4639 is in fact a very weak example of an AGN, demonstrating that AGNs exist over a large range of activity, from galaxies like NGC 4639 to distant quasars, where the parent galaxy is almost completely dominated by the emissions from the AGN.  Image credit: ESA/Hubble &amp; NASA  <b><a href="http://www.nasa.gov/audience/formedia/features/MP_Photo_Guidelines.html" rel="nofollow">NASA image use policy.</a></b>  <b><a href="http://www.nasa.gov/centers/goddard/home/index.html" rel="nofollow">NASA Goddard Space Flight Center</a></b> enables NASA’s mission through four scientific endeavors: Earth Science, Heliophysics, Solar System Exploration, and Astrophysics. Goddard plays a leading role in NASA’s accomplishments by contributing compelling scientific knowledge to advance the Agency’s mission.  <b>Follow us on <a href="http://twitter.com/NASAGoddardPix" rel="nofollow">Twitter</a></b>  <b>Like us on <a href="http://www.facebook.com/pages/Greenbelt-MD/NASA-Goddard/395013845897?ref=tsd" rel="nofollow">Facebook</a></b>  <b>Find us on <a href="http://instagrid.me/nasagoddard/?vm=grid" rel="nofollow">Instagram</a></b>   ',
#       'keywords': ['Hubble Sees Elegant Spiral Hiding a Hungry Monster',
#        'space',
#        'nasa',
#        'galaxy',
#        'hubble',
#        'hubblespacetelescope',
#        'spiralgalaxy',
#        'nasagoddard',
#        'ngc4639'],
#       'location': 'Greenbelt, MD',
#       'media_type': 'image',
#       'nasa_id': 'GSFC_20171208_Archive_e000539',
#       'title': 'Hubble Sees Elegant Spiral Hiding a Hungry Monster'}],
#     'links': [{'href': 'https://images-assets.nasa.gov/image/GSFC_20171208_Archive_e000539/GSFC_20171208_Archive_e000539~medium.jpg',
#       'rel': 'alternate',
#       'render': 'image',
#       'width': 1222,
#       'size': 213000,
#       'height': 1280},
#      {'href': 'https://images-assets.nasa.gov/image/GSFC_20171208_Archive_e000539/GSFC_20171208_Archive_e000539~small.jpg',
#       'rel': 'alternate',
#       'render': 'image',
#       'width': 611,
#       'size': 42000,
#       'height': 640},
#      {'href': 'https://images-assets.nasa.gov/image/GSFC_20171208_Archive_e000539/GSFC_20171208_Archive_e000539~thumb.jpg',
#       'rel': 'preview',
#       'render': 'image',
#       'width': 611,
#       'size': 42000,
#       'height': 640},
#      {'href': 'https://images-assets.nasa.gov/image/GSFC_20171208_Archive_e000539/GSFC_20171208_Archive_e000539~orig.jpg',
#       'rel': 'canonical',
#       'render': 'image'}]}],
#   'metadata': {'total_hits': 2}}}

# %%
nasa_image_search_data[0]
# I want to get something about the first image
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 nasa_image_search_data[0]
#
# KeyError: 0

# %%
images = nasa_image_search_data.get('collection',{}).get('items',[])
#With ChatGPT's help, I learn how to access data within json output, a little bit - need to learn more here

# %%
images[0]
# Out:
# {'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/collection.json',
#  'data': [{'center': 'GSFC',
#    'date_created': '2015-10-12T00:00:00Z',
#    'description': 'NGC 4639 is a beautiful example of a type of galaxy known as a barred spiral. It lies over 70 million light-years away in the constellation of\xa0Virgo and is one of about 1500 galaxies that make up the Virgo Cluster. In this image, taken by the NASA/ESA Hubble Space Telescope, one can clearly see the bar running through the bright, round core of the galaxy. Bars are found in around two thirds of spiral galaxies, and are thought to be a natural phase in their evolution. The galaxy’s spiral arms are sprinkled with bright regions of active star formation. Each of these tiny jewels is actually several hundred light-years across and contains hundreds or thousands of newly formed stars. But NGC 4639 also conceals a dark secret in its core — a massive black hole that is consuming the surrounding gas. This is known as an active galactic nucleus (AGN), and is revealed by characteristic features in the spectrum of light from the galaxy and by\xa0X-rays produced close to the black hole as the hot gas plunges towards it. Most galaxies are thought to contain a black hole at the centre. NGC 4639 is in fact a very weak example of an AGN, demonstrating that AGNs exist over a large range of activity, from galaxies like NGC 4639 to distant quasars, where the parent galaxy is almost completely dominated by the emissions from the AGN.',
#    'keywords': ['NGC 4639'],
#    'media_type': 'image',
#    'nasa_id': 'hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o',
#    'title': 'Elegant spiral hides a hungry monster'}],
#  'links': [{'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~medium.jpg',
#    'rel': 'alternate',
#    'render': 'image',
#    'width': 1222,
#    'size': 213000,
#    'height': 1280},
#   {'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~small.jpg',
#    'rel': 'alternate',
#    'render': 'image',
#    'width': 611,
#    'size': 42000,
#    'height': 640},
#   {'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~thumb.jpg',
#    'rel': 'preview',
#    'render': 'image',
#    'width': 611,
#    'size': 42000,
#    'height': 640},
#   {'href': 'https://images-assets.nasa.gov/image/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o/hubble-sees-elegant-spiral-hiding-a-hungry-monster_22037110968_o~orig.jpg',
#    'rel': 'canonical',
#    'render': 'image',
#    'height': 1340,
#    'width': 1280,
#    'size': 407000}]}

# %%
images[0].get('data',[])[0].get('title')
# Out:
# 'Elegant spiral hides a hungry monster'

# %% [markdown]
# The syntax is complicated... and confusing, need to study or come up with a better way/method to keep track/identify
# or break into smaller steps

# %% [markdown]
# I feel like it's exhausting to do one simple thing, maybe it gets better with experience and practice

# %% [markdown]
# P.S.

# %% [markdown]
# With these, few minutes of searching did not result in finding an easy tutorial, moved on to another source
# https://realpython.com/search?category=api&q=basic+api+tutorial
#
# https://www.freecodecamp.org/news/apis-for-beginners/ (I needed to watch a video)
